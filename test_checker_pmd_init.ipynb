# %%
import tensorflow as tf
from psychrnn.backend.models.basic import Basic
from psychrnn.backend.gain.basic2 import Basic2
from psychrnn.backend.gain.loss import rt_mask_mse_06, rt_mask_mse_07, rt_mask_mse_08
from psychrnn.tasks.checkerPmd import Checkerboard2AFC
from psychrnn.tasks.checkerPmdInit import Init

from tqdm import tqdm
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Generate a batch of trials

# %%
experiment = 'interactive'
name = 'basic'
dt = 10
tau = 50
T = 5000
N_batch = 50
N_rec = 100

task = Checkerboard2AFC(dt=dt, tau=tau, T=T, N_batch=N_batch, noise = 0.25)

# %%
params = task.get_task_params()
params
# Out:
# {'N_batch': 50,
#  'N_in': 2,
#  'N_out': 2,
#  'dt': 10,
#  'tau': 50,
#  'T': 5000,
#  'alpha': 0.2,
#  'N_steps': 500,
#  'coherence': [0, 1],
#  'noise': 0.25,
#  'target_onset': [250, 500],
#  'checker_onset': [500, 1000],
#  'accumulation_mask': 300,
#  'decision_threshold': 0.7,
#  'post_decision_baseline': 0.2,
#  'wait': 0.2,
#  'hi': 1,
#  'lo': 0}

# %%
[x, y, mask, allParams] = task.get_trial_batch()

trialNum = 1
# x[1]: left tartet evidence
# x[2]: right target evidence
trialIn = x[trialNum,:,:]
trialOut = y[trialNum,:,:]
trialMask = mask[trialNum,:,:]
time = np.linspace(0, task.T, int(task.T/task.dt))
# plot input to the model
plt.figure()
plt.plot(time, trialIn[:,0], label = 'left')
plt.plot(time, trialIn[:,1], label = 'right')
plt.legend()

# plot output to the model
plt.figure()
plt.plot(time, trialOut[:,0], label = 'left')
plt.plot(time, trialOut[:,1], label = 'right')
plt.legend()

print(allParams[trialNum])
# Out:
# {'coherence': 0.8914832894040708, 'noise': 0.25, 'accumulation_mask': 300, 'target_onset': 352, 'checker_onset': 575}

# %% [markdown]
# # Set network parameters

# %%
network_params = task.get_task_params()
network_params['name'] = name
network_params['N_rec'] = N_rec
network_params['rec_noise'] = 0.5

network_params["transfer_function"] = tf.nn.relu
network_params["output_transfer_function"] = tf.nn.sigmoid

network_params["loss_function"] = "rt_mask_mse"
network_params["rt_mask_mse"] = rt_mask_mse_07

# %%
try:
    model.destruct()
except:
    pass

model = Basic2(network_params)

# %% [markdown]
# # Set Training params and train

# %%
trials = 50000
train_params = {}
train_params['save_weights_path'] =  './init' #"./weights/checkerPmdBasic2InputNoise0.75"
train_params['training_iters'] = trials
train_params['learning_rate'] = .001
train_params['loss_epoch'] = 10
train_params['save_training_weights_epoch'] = 1000 / N_batch
train_params['training_weights_path'] = None

# %%
losses, initialTime, trainTime = model.train(task, train_params)
loss_name =  './init.txt' #"./losses/checkerPmdBasic2InputNoise0.75.txt"
print("Save losses to " + loss_name)
with open(loss_name, 'w') as f:
    for item in losses:
        f.write("%s\n" % item)
# Out:
# WARNING:tensorflow:From /home/tianwang/code/behaviorRNN/PsychRNN/psychrnn/backend/gain/basic2.py:132: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Iter 500, Minibatch Loss= 0.164254
# Iter 1000, Minibatch Loss= 0.121022
# Iter 1500, Minibatch Loss= 0.135837
# Iter 2000, Minibatch Loss= 0.134500
# Iter 2500, Minibatch Loss= 0.075297
# Iter 3000, Minibatch Loss= 0.042222
# Iter 3500, Minibatch Loss= 0.052107
# Iter 4000, Minibatch Loss= 0.048209
# Iter 4500, Minibatch Loss= 0.060042
# Iter 5000, Minibatch Loss= 0.038222
# Iter 5500, Minibatch Loss= 0.042601
# Iter 6000, Minibatch Loss= 0.029139
# Iter 6500, Minibatch Loss= 0.039741
# Iter 7000, Minibatch Loss= 0.027652
# Iter 7500, Minibatch Loss= 0.030355
# Iter 8000, Minibatch Loss= 0.031476
# Iter 8500, Minibatch Loss= 0.022206
# Iter 9000, Minibatch Loss= 0.025943
# Iter 9500, Minibatch Loss= 0.018065
# Iter 10000, Minibatch Loss= 0.017728
# Iter 10500, Minibatch Loss= 0.013409
# Iter 11000, Minibatch Loss= 0.018181
# Iter 11500, Minibatch Loss= 0.017457
# Iter 12000, Minibatch Loss= 0.022451
# Iter 12500, Minibatch Loss= 0.019739
# Iter 13000, Minibatch Loss= 0.016955
# Iter 13500, Minibatch Loss= 0.019087
# Iter 14000, Minibatch Loss= 0.011917
# Iter 14500, Minibatch Loss= 0.016030
# Iter 15000, Minibatch Loss= 0.019643
# Iter 15500, Minibatch Loss= 0.016792
# Iter 16000, Minibatch Loss= 0.027741
# Iter 16500, Minibatch Loss= 0.011858
# Iter 17000, Minibatch Loss= 0.015807
# Iter 17500, Minibatch Loss= 0.011118
# Iter 18000, Minibatch Loss= 0.012866
# Iter 18500, Minibatch Loss= 0.017084
# Iter 19000, Minibatch Loss= 0.012999
# Iter 19500, Minibatch Loss= 0.013855
# Iter 20000, Minibatch Loss= 0.014966
# Iter 20500, Minibatch Loss= 0.013388
# Iter 21000, Minibatch Loss= 0.014171
# Iter 21500, Minibatch Loss= 0.007702
# Iter 22000, Minibatch Loss= 0.011461
# Iter 22500, Minibatch Loss= 0.014410
# Iter 23000, Minibatch Loss= 0.013463
# Iter 23500, Minibatch Loss= 0.012066
# Iter 24000, Minibatch Loss= 0.011652
# Iter 24500, Minibatch Loss= 0.011511
# Iter 25000, Minibatch Loss= 0.007206
# Iter 25500, Minibatch Loss= 0.009185
# Iter 26000, Minibatch Loss= 0.007364
# Iter 26500, Minibatch Loss= 0.025584
# Iter 27000, Minibatch Loss= 0.010391
# Iter 27500, Minibatch Loss= 0.009582
# Iter 28000, Minibatch Loss= 0.010004
# Iter 28500, Minibatch Loss= 0.008734
# Iter 29000, Minibatch Loss= 0.010163
# Iter 29500, Minibatch Loss= 0.015221
# Iter 30000, Minibatch Loss= 0.009749
# Iter 30500, Minibatch Loss= 0.014775
# Iter 31000, Minibatch Loss= 0.010315
# Iter 31500, Minibatch Loss= 0.012719
# Iter 32000, Minibatch Loss= 0.009834
# Iter 32500, Minibatch Loss= 0.010605
# Iter 33000, Minibatch Loss= 0.009190
# Iter 33500, Minibatch Loss= 0.007123
# Iter 34000, Minibatch Loss= 0.004665
# Iter 34500, Minibatch Loss= 0.012039
# Iter 35000, Minibatch Loss= 0.008135
# Iter 35500, Minibatch Loss= 0.013044
# Iter 36000, Minibatch Loss= 0.006995
# Iter 36500, Minibatch Loss= 0.010735
# Iter 37000, Minibatch Loss= 0.007086
# Iter 37500, Minibatch Loss= 0.006002
# Iter 38000, Minibatch Loss= 0.008611
# Iter 38500, Minibatch Loss= 0.006403
# Iter 39000, Minibatch Loss= 0.008498
# Iter 39500, Minibatch Loss= 0.007765
# Iter 40000, Minibatch Loss= 0.004893
# Iter 40500, Minibatch Loss= 0.006766
# Iter 41000, Minibatch Loss= 0.005406
# Iter 41500, Minibatch Loss= 0.006725
# Iter 42000, Minibatch Loss= 0.007982
# Iter 42500, Minibatch Loss= 0.008797
# Iter 43000, Minibatch Loss= 0.011105
# Iter 43500, Minibatch Loss= 0.007544
# Iter 44000, Minibatch Loss= 0.008589
# Iter 44500, Minibatch Loss= 0.004147
# Iter 45000, Minibatch Loss= 0.005704
# Iter 45500, Minibatch Loss= 0.006935
# Iter 46000, Minibatch Loss= 0.006602
# Iter 46500, Minibatch Loss= 0.005441
# Iter 47000, Minibatch Loss= 0.012252
# Iter 47500, Minibatch Loss= 0.005356
# Iter 48000, Minibatch Loss= 0.006378
# Iter 48500, Minibatch Loss= 0.009686
# Iter 49000, Minibatch Loss= 0.009497
# Iter 49500, Minibatch Loss= 0.009573
# Optimization finished!
# Model saved in file: ./init
# Save losses to ./init.txt

# %%
plt.plot(losses)
plt.ylabel("Loss")
plt.xlabel("Training Iteration")
plt.title("Loss During Training")
# Out:
# Text(0.5, 1.0, 'Loss During Training')

# %% [markdown]
# # Test 5000 trials

# %%
trials = 5000
batches = int(np.ceil(trials / N_batch))

rnn_state = np.zeros((trials, task.N_steps, model.N_rec))
rnn_out = np.zeros((trials, task.N_steps, model.N_out))

coherence = np.zeros(trials)
target_onset = np.zeros(trials)
checker_onset = np.zeros(trials)
decision = np.zeros(trials)
rt = np.zeros(trials)

init_y_left = np.zeros(trials)

# %%
biasTask = Init(dt=dt, tau=tau, T=T, N_batch=N_batch, noise = 0.25, wait = [0.2, 0.5])

[x, y, mask, allParams] = biasTask.get_trial_batch()

trialNum = 1
# x[1]: left tartet evidence
# x[2]: right target evidence
trialIn = x[trialNum,:,:]
trialOut = y[trialNum,:,:]
trialMask = mask[trialNum,:,:]
time = np.linspace(0, biasTask.T, int(biasTask.T/task.dt))
# plot input to the model
plt.figure()
plt.plot(time, trialIn[:,0], label = 'left')
plt.plot(time, trialIn[:,1], label = 'right')
plt.legend()

# plot output to the model
plt.figure()
plt.plot(time, trialOut[:,0], label = 'left')
plt.plot(time, trialOut[:,1], label = 'right')
plt.legend()

print(allParams[trialNum])
# Out:
# {'coherence': 0.5340587829124845, 'noise': 0.25, 'accumulation_mask': 300, 'target_onset': 476, 'checker_onset': 730, 'init_y': array([0.24119118, 0.48134487])}

# %%
for b in tqdm(range(batches)):
    x, y, m, params = biasTask.get_trial_batch()
    outputs, states, inputs = model.test(x)
    
    start_index = N_batch * b
    end_index = N_batch * (b + 1)
    rnn_state[start_index:end_index] = states
    rnn_out[start_index:end_index] = outputs

    
    thr = np.where(outputs > 0.7)
    
    for i in range(N_batch):
        index = start_index + i
        
        coherence[index] = params[i]["coherence"]
        target_onset[index] = params[i]["target_onset"]
        checker_onset[index] = params[i]["checker_onset"]
        
        init_y_left[index] = params[i]["init_y"][0]
        
        thr_time = thr[1][thr[0]==i][0] if sum(thr[0]==i) > 0 else outputs.shape[1]
        thr_unit = thr[2][thr[0]==i][0] if sum(thr[0]==i) > 0 else np.argmax(outputs[i, -1])
        decision[index] = thr_unit
        rt[index] = thr_time*biasTask.dt - target_onset[index] - checker_onset[index]
# Out:
# 100%|██████████| 100/100 [00:50<00:00,  1.99it/s]

# %%
#onsets = [p["onset_time"] for p in params]
onsets = target_onset[-N_batch:] + checker_onset[-N_batch:]
rts = rt[-N_batch:]
for i in range(10):
    plt.figure()
    plt.plot(np.arange(0, 5000, 10), inputs[i, :, 0])
    plt.plot(np.arange(0, 5000, 10), inputs[i, :, 1])

    plt.figure()
    plt.plot(np.arange(0, 5000, 10), outputs[i, :, 0])
    plt.plot(np.arange(0, 5000, 10), outputs[i, :, 1])
    
    plt.vlines(onsets[i], 0, 1)
    plt.vlines(onsets[i] + rts[i], 0, 1)
    plt.hlines(0.7, 0, 5000)

# %%
correct_side = (coherence > 0.5)
correct_side = 1 - 1*correct_side


checker_df = pd.DataFrame({'trial' : np.arange(trials),
                           # the real coherence based on left and right (positive: left evidence dominant
                           # negative: right evidence dominant)
                           'coherence' : 2*coherence - 1,
                           'coherence_bin' : np.round(2*coherence - 1, 1),
                           'correct_side' : correct_side,
                           'target_onset' : target_onset,
                           'checker_onset' : checker_onset,
                           'decision' : decision,
                           'decision_time' : rt,
                           'correct_decision' : (decision == correct_side).astype(int),
                           'init_y_left' : init_y_left})
checker_mean = checker_df.groupby('coherence_bin').mean().reset_index()

print("Overall Accuracy: " + str(np.sum(checker_df["correct_decision"])/len(checker_df)))
print("Negative RT trials ratio: ", end = "")
print(np.sum(checker_df["decision_time"] < 0)/len(checker_df))
# Out:
# Overall Accuracy: 0.9302
# Negative RT trials ratio: 0.0296

# %%
#######################
## summary result save path

resultPath = "./checkerPmdInit.csv"
checker_df.to_csv(resultPath)

# %%
plt.figure(figsize=(13, 5))
plt.subplot(1,2,1)
plt.plot(checker_mean['coherence_bin'], 1-checker_mean['decision'])
plt.scatter(checker_mean['coherence_bin'], 1-checker_mean['decision'])
plt.xlabel("left coherence")
plt.ylabel("proportion of choosing left")
plt.subplot(1,2,2)
plt.plot(checker_mean['coherence_bin'], checker_mean['decision_time'])
plt.scatter(checker_mean['coherence_bin'], checker_mean['decision_time'])

# %% [markdown]
# # RT within same coherence

# %%
idx = 1
plt.figure(figsize=(15, 8))
for i in [0.9,0.7,0.5,0.3,0.1,0]:
    a = checker_df['coherence_bin'] == i
    groupCo = checker_df.loc[a,:]
    RT = groupCo["decision_time"]
    plt.subplot(2,3,idx)
    plt.hist(RT, bins = 25)
    plt.title("Coherence: " + str(i))
    idx = idx + 1

# %% [markdown]
# # Check the activity of each recurrent unit

# %%
trial_num = 5
plt.figure()
plt.subplot(211)
_ = plt.plot(np.arange(0, T, dt), rnn_state[trial_num,:,:])
plt.xlabel("time step (10ms)")
plt.ylabel("firing rate")
plt.subplot(212)
_ = plt.plot(np.arange(0, T, dt), rnn_out[trial_num,:,0], label = "left")
_ = plt.plot(np.arange(0, T, dt), rnn_out[trial_num,:,1], label = "right")
plt.legend()

# save the firing rate of of each unit and output
# trialDat = {'state':rnn_state, 'y':rnn_out}
# np.save("./stateActivityCheckerPmdInputNoise0.25.npy",trialDat)

# %%
# transpose the data and save as .mat file for analysis on matlab
temp = np.transpose(rnn_state, (2,1,0))
from scipy.io import savemat
mdic = {'temp': temp}
savemat("temp.mat", mdic)

# %% [markdown]
# ## Get PSTH of each unit

# %%
checker_df.head()
# Out:
#    trial  coherence  coherence_bin  correct_side  target_onset  checker_onset  \
# 0      0   0.249269            0.2             0         261.0          807.0
# 1      1  -0.074337           -0.1             1         351.0          522.0
# 2      2  -0.207367           -0.2             1         459.0          535.0
# 3      3   0.050925            0.1             0         423.0          916.0
# 4      4   0.648339            0.6             0         434.0          724.0
#
#    decision  decision_time  correct_decision  init_y_left  init_y_right
# 0       0.0          412.0                 1          0.0           0.0
# 1       1.0          297.0                 1          0.0           0.0
# 2       1.0          306.0                 1          0.0           0.0
# 3       1.0          741.0                 0          0.0           0.0
# 4       0.0          502.0                 1          0.0           0.0
# ERROR! Session/line number was not unique in database. History logging moved to new session 904

# %%
decision = checker_df['decision']

# %%
psth = np.zeros((rnn_state.shape[2],rnn_state.shape[1], 2))

for i in range(rnn_state.shape[2]):

    psth[i,:,0] = np.mean(rnn_state[decision == 0,:,i], axis = 0)
    psth[i,:,1] = np.mean(rnn_state[decision == 1,:,i], axis = 0)

# %%
# find left modulated units
mean_diff = np.sum(psth[:,:,0] - psth[:,:,1], axis = 1)

biasedInputMask = np.ones((N_rec, 2))
biasedInputMask[mean_diff > 0,0] = 2
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 907
